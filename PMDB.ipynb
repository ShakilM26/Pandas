# %% [markdown]
# <a href="https://colab.research.google.com/github/ShakilM26/Data-Cleaning-Practice/blob/main/PMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('cinema.csv')
df.head()
# Out:
#    Year              Name            Director             Genre  IMDB  \
# 0  2020             Tenet   Christopher nolan     Sci-fi/Action   7.4
# 1  2020              WW84       Patty Jenkins  Superhero/Action   5.4
# 2  2012  Django Unchained   Quentin Tarantino    Western/Action   8.4
# 3  2020            Onward         Dan Scanlon  Animation/Family   7.4
# 4  2019             Polar      Jonas Åkerlund   Action/Thriller   6.3
#
#    Rotten Tomatoes  Metacritic Country  Personal Rating Comics Animation  \
# 0               69          69     USA              7.5     no        no
# 1               58          60     USA              5.0    yes        no
# 2               87          81     USA              8.5     no        no
# 3               88          61     USA              7.0     no       yes
# 4               19          19     USA              6.0     no        no
#
#   TV_Series  Budget  Box_office Runtime  Google_user    Month
# 0        no   200.0       363.0     150           85  January
# 1        no   200.0       167.0     151           67  January
# 2        no   100.0       425.0     165           93  January
# 3        no   185.0       142.0     102           81  January
# 4        no     0.0         0.0     118           77  January

# %%
#check null value

df.isnull().sum()
# Out:
# Year               0
# Name               0
# Director           0
# Genre              0
# IMDB               0
# Rotten Tomatoes    0
# Metacritic         0
# Country            0
# Personal Rating    0
# Comics             0
# Animation          0
# TV_Series          0
# Budget             0
# Box_office         0
# Runtime            0
# Google_user        0
# Month              0
# dtype: int64

# %%
#check notnull value

df.notnull().sum()
# Out:
# Year               220
# Name               220
# Director           220
# Genre              220
# IMDB               220
# Rotten Tomatoes    220
# Metacritic         220
# Country            220
# Personal Rating    220
# Comics             220
# Animation          220
# TV_Series          220
# Budget             220
# Box_office         220
# Runtime            220
# Google_user        220
# Month              220
# dtype: int64

# %%
# Find specific columns null value

df['Year'].isnull().sum()
# Out:
# 0

# %%
# If there was any null value

df.dropna(axis=1, how='any').shape
# Out:
# (220, 17)

# %%
# How many movies have I seen
# 1st method

len(df[df['TV_Series']=='no'])
# Out:
# 206

# %%
# 2nd method

len(df[df['TV_Series'].str.contains('no')])
# Out:
# 206

# %%
# How many tv_series have I seen

len(df[df['TV_Series']=='yes'])
# Out:
# 14

# %%
# How many animation have I seen

len(df[df['Animation']=='yes'])
# Out:
# 27

# %%
# How many animation movies have I seen 

len(df[(df['TV_Series']=='no') & (df['Animation']=='yes')])
# Out:
# 26

# %%
# The answer is 26. Total animation result was 27. So  
# I can say there is one tv-series animation I have seen.

# %%
# Here it is 

df.loc[(df['TV_Series']=='yes') & (df['Animation']=='yes')]
# Out:
#      Year        Name       Director             Genre  IMDB  Rotten Tomatoes  \
# 173  2021  What...If?  Bryan Andrews  Superhero/Action   7.5               94
#
#      Metacritic Country  Personal Rating Comics Animation TV_Series  Budget  \
# 173          69     USA              7.5    yes       yes       yes     0.0
#
#      Box_office Runtime  Google_user     Month
# 173         0.0   30-37           88  November

# %%
# How many comics related movies have I seen 

len(df[(df['TV_Series']=='no') & (df['Comics']=='yes')])
# Out:
# 19

# %%
# How many comics related tv-series have I seen 

len(df[(df['TV_Series']=='yes') & (df['Comics']=='yes')])
# Out:
# 4

# %%
# How many comics related animation have I seen 

len(df[(df['Animation']=='yes') & (df['Comics']=='yes')])
# Out:
# 16

# %%
# Total comics related movies and tv-series 

len(df[df['Comics'].str.contains('yes')])
# Out:
# 23

# %%
# Here I have split my dataset into two parts. Before and after 2000.

after_2000 = len(df[df['Year']>=2000])
before_2000 = len(df[df['Year']<2000])
print(after_2000)
print(before_2000)
# Out:
# 180
# 40

# %%
x=df.iloc[150: 160, :]
x
# Out:
#      Year                  Name                     Director  \
# 150  2021               Kuruthi                 Manu Warrier
# 151  2008         Step brothers                   Adam McKay
# 152  2015     The Hateful Eight            Quentin Tarantino
# 153  2021              Free Guy                   Shawn Levy
# 154  2020            Paranormal  Amr Salama, Majid Al Ansari
# 155  1988              Die Hard               John McTiernan
# 156  1990            Die Hard 2                 Renny Harlin
# 157  2001           Vanilla Sky                Cameron Crowe
# 158  2012       Seven Psycopath              Martin McDonagh
# 159  1986  The name of the Rose          Jean-Jacques Annaud
#
#                   Genre  IMDB  Rotten Tomatoes  Metacritic Country  \
# 150      Crime/Thriller   7.7                0           0   India
# 151              Comedy   6.9               55          51     USA
# 152      Western/Action   7.8               74          68     USA
# 153    Action/Adventure   7.2               80          62     USA
# 154  Drama/Supernatural   8.5               96           0   Egypt
# 155     Action/Thriller   8.2               94          72     USA
# 156     Action/Thriller   7.1               69          67     USA
# 157     Sci-fi/Thriller   6.9               42          45     USA
# 158        Comedy/Crime   7.2               83          66      UK
# 159       Mystery/Crime   7.7               74          54   Italy
#
#      Personal Rating Comics Animation TV_Series  Budget  Box_office Runtime  \
# 150              7.5     no        no        no     4.5         0.0     122
# 151              6.5     no        no        no    65.0       128.0      98
# 152              7.5     no        no        no    55.0       157.0     187
# 153              7.0     no        no        no   110.0       332.0     115
# 154              8.0     no        no       yes     0.0         0.0   46-55
# 155              8.5     no        no        no    30.0       140.0     132
# 156              7.5     no        no        no    65.0       240.0     124
# 157              6.5     no        no        no    68.0       203.0     137
# 158              7.0     no        no        no    14.0        33.0     110
# 159              7.0     no        no        no    17.5        77.0     131
#
#      Google_user      Month
# 150           78  September
# 151           89    October
# 152           89    October
# 153           89    October
# 154           86    October
# 155           91    October
# 156           92    October
# 157           81    October
# 158           84    October
# 159           85    October

# %%
# Highest Rating of IMDB
# ? 

df[['IMDB', 'Name']].sort_values(by='IMDB', ascending=False).head()
# Out:
#      IMDB               Name
# 25    8.8               Dark
# 89    8.6  Kumbalangi Nights
# 50    8.6         Drishyam 2
# 219   8.6         Mindhunter
# 212   8.5            Mandela

# %%
# How many movies got 'Rotten Tomatoes 100'

df[df['Rotten Tomatoes']==100].count()[1]
# Out:
# 9

# %%
df[df['Rotten Tomatoes']==100][["Name"]]
# Out:
#                                    Name
# 55            Superman: Man of Tomorrow
# 98                      Batman Vs Robin
# 108                          Bad Genius
# 124   Batman: The Long Halloween Part 1
# 125    Batman: The Long Hallowin Part 2
# 133  Justice League Dark: Apokolips War
# 182                      Cool Hand Luke
# 205                       A Man Escaped
# 210                                   M

# %%
# Highest Rotten Tomatoes Rating
# 2nd method

df[['Rotten Tomatoes', 'Name']].sort_values(by='Rotten Tomatoes', ascending=False).head(10)
# Out:
#      Rotten Tomatoes                                Name
# 133              100  Justice League Dark: Apokolips War
# 98               100                     Batman Vs Robin
# 55               100           Superman: Man of Tomorrow
# 210              100                                   M
# 125              100    Batman: The Long Hallowin Part 2
# 205              100                       A Man Escaped
# 124              100   Batman: The Long Halloween Part 1
# 108              100                          Bad Genius
# 182              100                      Cool Hand Luke
# 44                99                         The Wailing

# %%
# I wanted to sort the movies that got 100 ratings according to the first letter of the name

df.sort_values(['Rotten Tomatoes', 'Name'], ascending=[False, True]).head(10)
# Out:
#      Year                                Name                      Director  \
# 205  1956                       A Man Escaped                Robert Bresson
# 108  2017                          Bad Genius           Nattawut Poonpiriya
# 98   2015                     Batman Vs Robin                     Jay Oliva
# 124  2021   Batman: The Long Halloween Part 1                  Chris Palmer
# 125  2021    Batman: The Long Hallowin Part 2                  Chris Palmer
# 182  1967                      Cool Hand Luke              Stuart Rosenberg
# 133  2020  Justice League Dark: Apokolips War  Christina Sotta, Matt Peters
# 210  1931                                   M                    Fritz Lang
# 55   2020           Superman: Man of Tomorrow                  Chris Palmer
# 44   2016                         The Wailing                   Na Hong-jin
#
#                   Genre  IMDB  Rotten Tomatoes  Metacritic   Country  \
# 205    War/Prison-Break   8.3              100           0    France
# 108      Thriller/Heist   7.6              100           0  Thailand
# 98     Action/Adventure   7.1              100          50       USA
# 124    Superhero/Action   7.3              100           0       USA
# 125    Superhero/Action   7.2              100           0       USA
# 182  Drama/Prison-Break   8.1              100          92       USA
# 133    Superhero/Action   7.8              100           0       USA
# 210      Thriller/Crime   8.3              100           0   Germany
# 55     Action/Adventure   6.4              100          81       USA
# 44               Horror   7.5               99          81    Korean
#
#      Personal Rating Comics Animation TV_Series  Budget  Box_office Runtime  \
# 205              8.0     no        no        no     0.0         0.0      99
# 108              8.0     no        no        no     9.0        42.0     130
# 98               7.0    yes       yes        no     0.0         0.0      80
# 124              7.0    yes       yes        no     0.0         0.0      85
# 125              7.5    yes       yes        no     0.0         0.0      87
# 182              8.0     no        no        no     3.2        16.0     126
# 133              7.5    yes       yes        no     0.0         0.0      90
# 210              8.5     no        no        no     0.0         0.0     111
# 55               7.0    yes       yes        no     0.0         0.0      86
# 44               7.0     no        no        no     8.0        51.0     156
#
#      Google_user      Month
# 205           90   December
# 108           94     August
# 98            86       July
# 124           83     August
# 125           80  September
# 182           87   November
# 133           72  September
# 210           47   December
# 55            73        May
# 44            84      April

# %%
# Highest Metacritic Rating

df[['Metacritic', 'Name']].sort_values(by='Metacritic', ascending=False).head(10)
# Out:
#      Metacritic                     Name
# 29           99  The night of the hunter
# 71           96              Ratatouille
# 209          95       The Social Network
# 187          94    The French Connection
# 182          92           Cool Hand Luke
# 81           92               Annie Hall
# 32           91   No country for old man
# 120          91                      Her
# 74           90       Mad Max: Fury Road
# 171          89                    Alien

# %%
# I didn't get some movie Rotten Tomatoes rating, instead I put it at zero. 
# How many movies have I given such a zero?

len(df[df['Rotten Tomatoes']==0])
# Out:
# 14

# %%
# Also It happened with Metacritic.

len(df[df['Metacritic']==0])
# Out:
# 32

# %%
# Specific Data Find
# How many Christopher Nolan movies did I watch last year?

df.loc[df['Director'] == 'Christopher nolan']
df[df['Director'].str.contains('Christopher nolan')]
# Out:
#      Year       Name           Director           Genre  IMDB  \
# 0    2020      Tenet  Christopher nolan   Sci-fi/Action   7.4
# 88   2002   Insomnia  Christopher nolan  Thriller/Drama   7.2
# 105  1998  Following  Christopher nolan  Thriller/Crime   7.5
#
#      Rotten Tomatoes  Metacritic Country  Personal Rating Comics Animation  \
# 0                 69          69     USA              7.5     no        no
# 88                92          78     USA              7.0     no        no
# 105               81          60      UK              7.0     no        no
#
#     TV_Series  Budget  Box_office Runtime  Google_user    Month
# 0          no   200.0       363.0     150           85  January
# 88         no    46.0       114.0     118           92     June
# 105        no     6.0        48.0      70           82     July

# %%
# Also we can find it another way

df.query("Director=='Christopher nolan'")
# Out:
#      Year       Name           Director           Genre  IMDB  \
# 0    2020      Tenet  Christopher nolan   Sci-fi/Action   7.4
# 88   2002   Insomnia  Christopher nolan  Thriller/Drama   7.2
# 105  1998  Following  Christopher nolan  Thriller/Crime   7.5
#
#      Rotten Tomatoes  Metacritic Country  Personal Rating Comics Animation  \
# 0                 69          69     USA              7.5     no        no
# 88                92          78     USA              7.0     no        no
# 105               81          60      UK              7.0     no        no
#
#     TV_Series  Budget  Box_office Runtime  Google_user    Month
# 0          no   200.0       363.0     150           85  January
# 88         no    46.0       114.0     118           92     June
# 105        no     6.0        48.0      70           82     July

# %%
# Yearly movie list

sns.histplot(x='Year', data=df, bins=15)

# %%
sns.boxplot(x='Year', data=df)

# %%
df.Genre.value_counts().head(10).plot(kind='bar')

# %%
sns.scatterplot(x='Year', y='Budget', data=df, palette='summer')

# %%
df.plot(kind='scatter', x='Year', y='Budget', color='green', alpha=0.4)

# %%
s=df.sort_values(by='IMDB', ascending=False)[['Name', 'IMDB']].head()
s
# Out:
#                   Name  IMDB
# 25                Dark   8.8
# 89   Kumbalangi Nights   8.6
# 50          Drishyam 2   8.6
# 219         Mindhunter   8.6
# 212            Mandela   8.5

# %%
df.sort_values('IMDB', ascending=False).groupby('Genre')[['Name', 'Genre']].head()
# Out:
#                         Name                         Genre
# 25                      Dark                        Sci-fi
# 89         Kumbalangi Nights                 Drama/Romance
# 50                Drishyam 2                   Crime/Drama
# 219               Mindhunter  Psychological Thriller/Crime
# 212                  Mandela                  Comedy/Drama
# ..                       ...                           ...
# 163                  Knowing               Sci-fi/Thriller
# 148           Murder Mystery                Comedy/Mystery
# 142              Reminicense               Sci-fi/Thriller
# 65                     Mulan                Action/Fantasy
# 118  The Woman in the Window              Mystery/Thriller
#
# [176 rows x 2 columns]

# %%
av=df.groupby('Year').Box_office.agg(['count', 'mean'])
av.tail()
# Out:
#       count        mean
# Year
# 2017      9   52.000000
# 2018     10   93.800000
# 2019     11  144.454545
# 2020     28   72.107143
# 2021     35  151.380000

# %%
a=df['Budget'].groupby(df['Year']).describe()
a
# Out:
#       count       mean        std   min     25%    50%      75%    max
# Year
# 1927    1.0   0.000000        NaN   0.0   0.000   0.00    0.000    0.0
# 1931    1.0   0.000000        NaN   0.0   0.000   0.00    0.000    0.0
# 1954    1.0   5.000000        NaN   5.0   5.000   5.00    5.000    5.0
# 1955    1.0   6.000000        NaN   6.0   6.000   6.00    6.000    6.0
# 1956    1.0   0.000000        NaN   0.0   0.000   0.00    0.000    0.0
# 1967    1.0   3.200000        NaN   3.2   3.200   3.20    3.200    3.2
# 1971    1.0   2.000000        NaN   2.0   2.000   2.00    2.000    2.0
# 1974    1.0   1.600000        NaN   1.6   1.600   1.60    1.600    1.6
# 1975    1.0   9.000000        NaN   9.0   9.000   9.00    9.000    9.0
# 1976    1.0   4.500000        NaN   4.5   4.500   4.50    4.500    4.5
# 1977    1.0   4.000000        NaN   4.0   4.000   4.00    4.000    4.0
# 1978    1.0  15.000000        NaN  15.0  15.000  15.00   15.000   15.0
# 1979    1.0  11.000000        NaN  11.0  11.000  11.00   11.000   11.0
# 1980    1.0  18.000000        NaN  18.0  18.000  18.00   18.000   18.0
# 1982    1.0  30.000000        NaN  30.0  30.000  30.00   30.000   30.0
# 1983    1.0   6.200000        NaN   6.2   6.200   6.20    6.200    6.2
# 1984    2.0  14.000000  18.384776   1.0   7.500  14.00   20.500   27.0
# 1985    2.0  28.000000  22.627417  12.0  20.000  28.00   36.000   44.0
# 1986    2.0  18.250000   1.060660  17.5  17.875  18.25   18.625   19.0
# 1988    3.0  25.333333  18.448125   5.0  17.500  30.00   35.500   41.0
# 1989    1.0  45.000000        NaN  45.0  45.000  45.00   45.000   45.0
# 1990    2.0  47.500000  24.748737  30.0  38.750  47.50   56.250   65.0
# 1992    2.0  18.500000  23.334524   2.0  10.250  18.50   26.750   35.0
# 1993    2.0  25.000000  26.870058   6.0  15.500  25.00   34.500   44.0
# 1994    1.0  16.000000        NaN  16.0  16.000  16.00   16.000   16.0
# 1995    3.0  88.333333  87.511904   0.0  45.000  90.00  132.500  175.0
# 1996    1.0   7.000000        NaN   7.0   7.000   7.00    7.000    7.0
# 1998    3.0   2.466667   3.139002   0.0   0.700   1.40    3.700    6.0
# 2000    1.0   7.000000        NaN   7.0   7.000   7.00    7.000    7.0
# 2001    5.0  79.200000  21.993181  60.0  68.000  68.00   85.000  115.0
# 2002    4.0  59.500000  40.245083  10.0  37.000  63.00   85.500  102.0
# 2003    2.0  16.850000  18.596908   3.7  10.275  16.85   23.425   30.0
# 2004    4.0  54.000000  45.723809   6.0  24.000  50.00   80.000  110.0
# 2005    3.0  26.333333  25.106440   0.0  14.500  29.00   39.500   50.0
# 2006    6.0  48.666667  64.589989   0.0   4.750  14.50   87.250  150.0
# 2007    4.0  77.500000  54.237134  25.0  43.750  67.50  101.250  150.0
# 2008    3.0  50.000000  30.413813  15.0  40.000  65.00   67.500   70.0
# 2009    5.0  27.600000  24.006249   0.0   5.000  33.00   50.000   50.0
# 2010    5.0  23.000000  17.944358   0.0   8.000  30.00   37.000   40.0
# 2011    6.0  44.666667  32.494102  15.0  21.250  31.00   70.000   90.0
# 2012    7.0  85.285714  54.450939  14.0  52.500  78.00  110.000  180.0
# 2013    4.0  57.000000  59.604250   0.0  17.250  46.50   86.250  135.0
# 2014    9.0  84.666667  98.140206   0.0  13.000  25.00  135.000  280.0
# 2015   13.0  53.769231  61.261943   0.0  12.000  30.00   61.000  170.0
# 2016    6.0  24.416667  38.624366   0.0   2.000   8.25   24.625  100.0
# 2017    9.0  44.777778  46.504779   0.0   9.000  29.00   60.000  130.0
# 2018   10.0  26.400000  30.082110   0.0   2.000   9.50   55.250   70.0
# 2019   11.0  49.681818  72.338881   0.0   3.250   8.00   72.500  180.0
# 2020   28.0  50.571429  72.289249   0.0   0.000   7.00   67.500  200.0
# 2021   35.0  93.168571  89.531430   0.0   0.000  70.00  180.000  280.0

# %%
# Remove comma from Runtime column (TV Series)
# There was an comma. When analyze this dataset I remove it
# df['Runtime']=df['Runtime'].replace(',', '', regex=True)

# %%
df['Runtime']=df.Runtime.apply(lambda x: x.replace('-', '')).astype('int64')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             220 non-null    int64
#  1   Name             220 non-null    object
#  2   Director         220 non-null    object
#  3   Genre            220 non-null    object
#  4   IMDB             220 non-null    float64
#  5   Rotten Tomatoes  220 non-null    int64
#  6   Metacritic       220 non-null    int64
#  7   Country          220 non-null    object
#  8   Personal Rating  220 non-null    float64
#  9   Comics           220 non-null    object
#  10  Animation        220 non-null    object
#  11  TV_Series        220 non-null    object
#  12  Budget           220 non-null    float64
#  13  Box_office       220 non-null    float64
#  14  Runtime          220 non-null    int64
#  15  Google_user      220 non-null    int64
#  16  Month            220 non-null    object
# dtypes: float64(4), int64(5), object(8)
# memory usage: 29.3+ KB

# %%
s=df.groupby('Country').Name.count()
s.sort_values(ascending=False).head(5)
# Out:
# Country
# USA       149
# Korean     21
# UK         17
# India       9
# Japan       6
# Name: Name, dtype: int64

# %%
s.plot(kind='bar', color='black')

# %%
plt.plot(s, ls='--')
plt.xticks(rotation=90)
plt.show()
