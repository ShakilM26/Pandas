# %%
import pandas as pd

# %%
df = pd.read_csv('world population.csv')

# %%
df = df.sample(frac=0.2)

# %%
df
# Out:
#      Rank    Country(or dependency) Population(2020) Yearly_Change  \
# 212   214                    Monaco           39,242        0.71 %
# 1       2                     India    1,380,004,385        0.99 %
# 114   115                   Denmark        5,792,202        0.35 %
# 7       8                Bangladesh      164,689,383        1.01 %
# 25     26                   Myanmar       54,409,800        0.67 %
# 32     33                   Algeria       43,851,044        1.85 %
# 232   234                   Tokelau            1,357        1.27 %
# 117   118                  Slovakia        5,459,642        0.05 %
# 231   233                      Niue            1,626        0.68 %
# 148   149                  Slovenia        2,078,938        0.01 %
# 230   232          Falkland Islands            3,480        3.05 %
# 221   223              Cook Islands           17,564        0.09 %
# 91     92                  Honduras        9,904,607        1.63 %
# ...

# %% [markdown]
# #### Now remove % and change cols data type

# %%
data_sample['Yearly_Change'] = list(map(lambda x: x[:-1], data_sample['Yearly_Change'].values))
data_sample['World_Share'] = list(map(lambda x: x[:-1], data_sample['World_Share'].values))

# %%
data_sample['Yearly_Change'] = [float(x) for x in data_sample['Yearly_Change'].values]
data_sample['World_Share'] = [float(x) for x in data_sample['World_Share'].values]

# %%
data_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47 entries, 231 to 59
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Rank                    47 non-null     int64
#  1   Country(or dependency)  47 non-null     object
#  2   Population(2020)        47 non-null     object
#  3   Yearly_Change           47 non-null     float64
#  4   Net_Change              47 non-null     object
#  5   Density(P/Km²)          47 non-null     object
#  6   Land_Area(Km²)          47 non-null     object
#  7   Migrants(net)           37 non-null     object
#  8   Fertility_Rate          47 non-null     object
#  9   Median_Age              47 non-null     object
#  10  Urban _Pop %            47 non-null     object
#  11  World_Share             47 non-null     float64
#  12  Continent               47 non-null     object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 5.1+ KB
